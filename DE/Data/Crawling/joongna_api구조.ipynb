# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
from selenium import webdriver
import time
import datetime

def get_inner_numbers(page):
    # WebDriver 경로 설정
    # path = "path_to_chromedriver"  # 여기에 실제 ChromeDriver 경로를 입력

    # WebDriver 인스턴스 생성 (Chrome 브라우저)
    driver = webdriver.Chrome(executable_path=r'C:\python\no_Yongsan_yes_Doksan\DE\chromedriver.exe')

    # 페이지 로드
    url = f"https://cafe.naver.com/joonggonara?iframe_url=/ArticleList.nhn%3Fsearch.clubid=10050146%26search.menuid=334%26search.boardtype=L%26search.totalCount=151%26search.cafeId=10050146%26search.page={page}"
    driver.get(url)

    # 페이지가 완전히 로드될 때까지 대기
    time.sleep(5)

    # iframe으로 이동
    driver.switch_to.frame('cafe_main')

    # 페이지 소스를 가져옴
    html = driver.page_source

    # BeautifulSoup 객체 생성
    soup = BeautifulSoup(html, 'html.parser')

    # inner_number 찾기
    inner_numbers = soup.find_all('div', {'class': 'inner_number'})

    # WebDriver 종료
    driver.quit()

    # inner_numbers를 텍스트로 변환하여 리스트로 반환
    return [num.text.strip() for num in inner_numbers]

# 'writeDate'를 datetime 객체로 변환하는 함수
def convert_write_date(timestamp):
    return datetime.datetime.fromtimestamp(timestamp / 1000) if timestamp else ''

def ju(page):
    # API URL을 쉽게 바꿀 수 있도록 만든 base url
    base_api_url = "https://apis.naver.com/cafe-web/cafe-articleapi/v2.1/cafes/10050146/articles/{}?query=&menuId=334&boardType=L&useCafeId=true&requestFrom=A"

    # inner_number 가져오기
    inner_numbers = get_inner_numbers(page)

    # API를 사용하여 데이터 가져오기
    data_list = []
    for num in inner_numbers:
        api_url = base_api_url.format(num)
        api_res = requests.get(api_url)
        api_data = api_res.json()  # API response to json

        # print(api_data)  # print the API response

        # 'result'가 존재하고 그 아래에 'article'이 존재하는지 확인
        if 'result' in api_data and 'article' in api_data['result']:
        # 원하는 데이터를 추출하고 이를 data_list에 추가
            data = api_data['result']['saleInfo']  # JSON 구조에 따라 수정
            menu_name = data.get('menu', {}).get('name', '')
            category1 = data.get('category1','')
            price = data.get('price','')

            data_list.append({
                'category1' : category1,
                'price' : price
            })

    df = pd.DataFrame(data_list)
    df.to_csv("data.csv",index=False,encoding = 'utf-8-sig')

# %%
ju(1)
# Out:
# C:\Users\영호\AppData\Local\Temp\ipykernel_28336\2018375352.py:14: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=r'C:\python\no_Yongsan_yes_Doksan\DE\chromedriver.exe')

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
from selenium import webdriver
import time
import datetime
import pprint

def get_inner_numbers(page):
    # WebDriver 경로 설정
    # path = "path_to_chromedriver"  # 여기에 실제 ChromeDriver 경로를 입력

    # WebDriver 인스턴스 생성 (Chrome 브라우저)
    driver = webdriver.Chrome(executable_path=r'C:\python\no_Yongsan_yes_Doksan\DE\chromedriver.exe')

    # 페이지 로드
    url = f"https://cafe.naver.com/joonggonara?iframe_url=/ArticleList.nhn%3Fsearch.clubid=10050146%26search.menuid=334%26search.boardtype=L%26search.totalCount=151%26search.cafeId=10050146%26search.page={page}"
    driver.get(url)

    # 페이지가 완전히 로드될 때까지 대기
    time.sleep(5)

    # iframe으로 이동
    driver.switch_to.frame('cafe_main')

    # 페이지 소스를 가져옴
    html = driver.page_source

    # BeautifulSoup 객체 생성
    soup = BeautifulSoup(html, 'html.parser')

    # inner_number 찾기
    inner_numbers = soup.find_all('div', {'class': 'inner_number'})

    # WebDriver 종료
    driver.quit()

    # inner_numbers를 텍스트로 변환하여 리스트로 반환
    return [num.text.strip() for num in inner_numbers]

# 'writeDate'를 datetime 객체로 변환하는 함수
def convert_write_date(timestamp):
    return datetime.datetime.fromtimestamp(timestamp / 1000) if timestamp else ''

def ju(page):
    # API URL을 쉽게 바꿀 수 있도록 만든 base url
    base_api_url = "https://apis.naver.com/cafe-web/cafe-articleapi/v2.1/cafes/10050146/articles/{}?query=&menuId=334&boardType=L&useCafeId=true&requestFrom=A"

    # inner_number 가져오기
    inner_numbers = get_inner_numbers(page)

    # API를 사용하여 데이터 가져오기
    data_list = []
    for num in inner_numbers:
        api_url = base_api_url.format(num)
        api_res = requests.get(api_url)
        api_data = api_res.json()  # API response to json

        pprint.pprint(api_data)  # print the API response

# %%
ju(1)
# Out:
# C:\Users\영호\AppData\Local\Temp\ipykernel_28336\1127867596.py:15: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=r'C:\python\no_Yongsan_yes_Doksan\DE\chromedriver.exe')
# {'result': {'advert': {'daAdvertDivId': 'DaAdvert',
#                        'daAdvertUnitId': 'm_cafe',
#                        'type': 'DA'},
#             'article': {'commentCount': 0,
#                         'contentHtml': '<div class="se-viewer '
#                                        'se-theme-default" lang="ko-KR">\n'
#                                        '    <!-- SE_DOC_HEADER_START -->\n'
#                                        '    <!--@CONTENTS_HEADER-->\n'
#                                        '    <!-- SE_DOC_HEADER_END -->\n'
#                                        '    <div class="se-main-container">\n'
#                                        '                <div '
#                                        'class="se-component se-text '
#                                        'se-l-default" '
#                                        'id="SE-afab82fc-d5e3-4aab-9fc0-e5e02f45fcdf">\n'
#                                        '                    <div '
#                                        'class="se-component-content">\n'
#                                        '                        <div '
#                                        'class="se-section se-section-text '
#                                        'se-l-default">\n'
#                                        '                            <div '
#                                        'class="se-module se-module-text">\n'
#                                        '                                    '
#                                        '<!-- SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " style="" '
#                                        'id="SE-3501edcd-d039-4f9e-8ca7-0352e45d3b19"><span '
#                                        'style="" class="se-fs- se-ff-   " '
#                                        'id="SE-8438ce33-211e-4f51-8abb-bad52026691c">삼성노트북배터리 '
#                                        'NT500R5H 노트북 내장배터리 팝니다.</span></p><!-- '
#                                        '} SE-TEXT --><!-- SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " style="" '
#                                        'id="SE-f749af4a-623a-4bd7-9305-26f048e11f47"><span '
#                                        'style="" class="se-fs- se-ff-   " '
#                                        'id="SE-26281ce5-7755-4b49-be98-6ee661d6abe0">\u200b</span></p><!-- '
#                                        '} SE-TEXT --><!-- SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " style="" '
#                                        'id="SE-cd62f592-e858-4860-841b-4f34e4b9ad14"><span '
#                                        'style="" class="se-fs- se-ff-   " '
#                                        'id="SE-c156def1-846e-4fce-9dad-68be7fd1e22f">현재 '
#                                        '배터리 잔량은 2시간 57분으로 찍히네요. '
#                                        '</span></p><!-- } SE-TEXT --><!-- '
#                                        'SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " style="" '
#                                        'id="SE-43af8fc5-a933-475a-8e05-f74f5e62c9f2"><span '
#                                        'style="" class="se-fs- se-ff-   " '
#                                        'id="SE-9ab939e5-2478-4c6f-823d-182bdd395081">\u200b</span></p><!-- '
#                                        '} SE-TEXT --><!-- SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " style="" '
#                                        'id="SE-469ba957-aa7d-40bf-95e1-5cb1792e2d9c"><span '
#                                        'style="" class="se-fs- se-ff-   " '
#                                        'id="SE-b58f16cf-a2b4-4bb7-8c30-037fbd2078c1">나사 '
#                                        '4개 함께 드립니다.</span></p><!-- } SE-TEXT '
#                                        '--><!-- SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " style="" '
#                                        'id="SE-b9856f06-0246-4aac-9080-e1ff351755fe"><span '
#                                        'style="" class="se-fs- se-ff-   " '
#                                        'id="SE-639ddb54-7da8-421b-bf13-8d4b1a855392">\u200b</span></p><!-- '
#                                        '} SE-TEXT --><!-- SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " style="" '
#                                        'id="SE-c7cf5025-7f6a-4b05-8af2-d6d25c495fa8"><span '
#                                        'style="" class="se-fs- se-ff-   " '
#                                        'id="SE-3e83252b-e84a-4f46-bfe6-e9b9b6878d8d">필요하신 '
#                                        '분은 문자주세요~</span></p><!-- } SE-TEXT '
#                                        '-->\n'
#                                        '                            </div>\n'
#                                        '                        </div>\n'
#                                        '                    </div>\n'
#                                        '                </div>                '
#                                        '<div class="se-component se-image '
#                                        'se-l-default" '
#                                        'id="SE-fe8521e9-0d09-4928-80e5-84ca5fff10c2">\n'
#                                        '                    <div '
#                                        'class="se-component-content '
#                                        'se-component-content-normal">\n'
#                                        '                        <div '
#                                        'class="se-section se-section-image '
#                                        'se-l-default se-section-align-center" '
#                                        'style="max-width:550px;">\n'
#                                        '                                <div '
#                                        'class="se-module se-module-image" '
#                                        'style="">\n'
#                                        '                                    <a '
#                                        'href="#" class="se-module-image-link '
#                                        '__se_image_link __se_link" style="" '
#                                        'onclick="return false;" '
#                                        'data-linktype="img" '
#                                        'data-linkdata=\'{"id" : '
#                                        '"SE-fe8521e9-0d09-4928-80e5-84ca5fff10c2", '
#                                        '"src" : '
#                                        '"https://cafeptthumb-phinf.pstatic.net/MjAyMzA1MjRfMjYy/MDAxNjg0ODg3NTczODY1.rvV_M8qUahjqI5MZvrY6f3cbN7C1Nozl2IBQrB8WmrMg.4EgE9o6lniaEMakzARVn7YoAImhe3_8NoYU3P_ZGL34g.JPEG/1-1.jpg", '
#                                        '"originalWidth" : "550", '
#                                        '"originalHeight" : "287", "linkUse" : '
#                                        '"false", "link" : ""}\'>\n'
#                                        '                                        '
#                                        '<img '
#                                        'src="https://cafeptthumb-phinf.pstatic.net/MjAyMzA1MjRfMjYy/MDAxNjg0ODg3NTczODY1.rvV_M8qUahjqI5MZvrY6f3cbN7C1Nozl2IBQrB8WmrMg.4EgE9o6lniaEMakzARVn7YoAImhe3_8NoYU3P_ZGL34g.JPEG/1-1.jpg?type=w1600" '
#                                        'alt="" class="se-image-resource" />\n'
#                                        '                                    '
#                                        '</a>\n'
#                                        '                                '
#                                        '</div>\n'
#                                        '                        </div>\n'
#                                        '                    </div>\n'
#                                        '                </div>\n'
#                                        '                <div '
#                                        'class="se-component se-image '
#                                        'se-l-default" '
#                                        'id="SE-b11ea674-1f65-4df0-ad9a-e2195464f4a1">\n'
#                                        '                    <div '
#                                        'class="se-component-content '
#                                        'se-component-content-normal">\n'
#                                        '                        <div '
#                                        'class="se-section se-section-image '
#                                        'se-l-default se-section-align-center" '
#                                        'style="max-width:550px;">\n'
#                                        '                                <div '
#                                        'class="se-module se-module-image" '
#                                        'style="">\n'
#                                        '                                    <a '
#                                        'href="#" class="se-module-image-link '
#                                        '__se_image_link __se_link" style="" '
#                                        'onclick="return false;" '
#                                        'data-linktype="img" '
#                                        'data-linkdata=\'{"id" : '
#                                        '"SE-b11ea674-1f65-4df0-ad9a-e2195464f4a1", '
#                                        '"src" : '
#                                        '"https://cafeptthumb-phinf.pstatic.net/MjAyMzAzMDdfMjI4/MDAxNjc4MTgzNzE0NTAx.xy7r9_rJhuRhsWw26NYtxyqaijxJ4IpBFtRF9ZlK9Hgg.lGB7IvaYZXfif3p-s8rxn7WGK7Pt3m6AjptxT_XYRAUg.JPEG/1-2.jpg?type=w1600", '
#                                        '"originalWidth" : "550", '
#                                        '"originalHeight" : "1054", "linkUse" : '
#                                        '"false", "link" : ""}\'>\n'
#                                        '                                        '
#                                        '<img '
#                                        'src="https://cafeptthumb-phinf.pstatic.net/MjAyMzAzMDdfMjI4/MDAxNjc4MTgzNzE0NTAx.xy7r9_rJhuRhsWw26NYtxyqaijxJ4IpBFtRF9ZlK9Hgg.lGB7IvaYZXfif3p-s8rxn7WGK7Pt3m6AjptxT_XYRAUg.JPEG/1-2.jpg?type=w1600" '
#                                        'alt="" class="se-image-resource" />\n'
#                                        '                                    '
#                                        '</a>\n'
#                                        '                                '
#                                        '</div>\n'
#                                        '                        </div>\n'
#                                        '                    </div>\n'
#                                        '                </div>\n'
#                                        '                <div '
#                                        'class="se-component se-text '
#                                        'se-l-default" '
#                                        'id="SE-a32f3bb1-03ed-4b1e-b6d4-29ded6c8972a">\n'
#                                        '                    <div '
#                                        'class="se-component-content">\n'
#                                        '                        <div '
#                                        'class="se-section se-section-text '
#                                        'se-l-default">\n'
#                                        '                            <div '
#                                        'class="se-module se-module-text">\n'
#                                        '                                    '
#                                        '<!-- SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " style="" '
#                                        'id="SE-c8b3e0fb-0f2d-48b1-a479-12d09503a970"><span '
#                                        'style="color:#000000;background-color:#ffffff;" '
#                                        'class="se-fs-fs13 '
#                                        'se-ff-nanumbarungothic  se-style-unset '
#                                        '" '
#                                        'id="SE-01a4602a-46f9-4a5f-9caf-65c11a7fe25d"><b>(택배착불/※선불시+3000/전자제품 '
#                                        '특성상 반품불가)</b></span></p><!-- } SE-TEXT '
#                                        '--><!-- SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " '
#                                        'style="line-height:1.3;" '
#                                        'id="SE-f695c7b7-c0b9-4668-bf44-2a5ddd726df3"><span '
#                                        'style="color:#000000;" '
#                                        'class="se-fs-fs13 '
#                                        'se-ff-nanumbarungothic  se-style-unset '
#                                        '" '
#                                        'id="SE-fd155db6-6193-4f17-a4c2-5a6149644b8b">\u200b</span></p><!-- '
#                                        '} SE-TEXT --><!-- SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " '
#                                        'style="line-height:1.3;" '
#                                        'id="SE-8faff0e7-d8a9-48e8-b6ae-be9a7f7625f0"><span '
#                                        'style="color:#000000;background-color:#ffffff;" '
#                                        'class="se-fs-fs13 '
#                                        'se-ff-nanumbarungothic  se-style-unset '
#                                        '" '
#                                        'id="SE-7ec90b1f-3c26-4b68-bed9-07797df3e1ea">직거래는 '
#                                        '대구/경산에서 가능하고 '
#                                        '서울,부산,인천,수원,대전,울산,창원,세종,구미,영천 등 타지역은 '
#                                        '풀박스 택배로 보내드립니다(※전자제품 특성상 '
#                                        '반품불가)</span></p><!-- } SE-TEXT --><!-- '
#                                        'SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " '
#                                        'style="line-height:1.3;" '
#                                        'id="SE-80de4b13-7bda-41a0-be8f-855959675961"><span '
#                                        'style="color:#000000;" '
#                                        'class="se-fs-fs13 '
#                                        'se-ff-nanumbarungothic  se-style-unset '
#                                        '" '
#                                        'id="SE-cc8e2393-0095-4929-a714-943c589ae3cb">\u200b</span></p><!-- '
#                                        '} SE-TEXT --><!-- SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " '
#                                        'style="line-height:1.3;" '
#                                        'id="SE-f93b8016-477f-49ec-bb60-7069681d170e"><span '
#                                        'style="color:#000000;background-color:#ffffff;" '
#                                        'class="se-fs-fs13 '
#                                        'se-ff-nanumbarungothic  se-style-unset '
#                                        '" '
#                                        'id="SE-0094d78f-725a-4f4f-847d-a21bf4285a5f"><b>구입하실 '
#                                        '분은 시간 상관없이 문자 '
#                                        '남겨주세요.O1O.4288.O829</b></span><span '
#                                        'style="color:#ffffff;background-color:#ffffff;" '
#                                        'class="se-fs-fs13 '
#                                        'se-ff-nanumbarungothic  se-style-unset '
#                                        '" '
#                                        'id="SE-43dbc735-6f72-4cda-ad2f-c69adc540200">성남,의정부,안양,부천,광명,평택,동두천,안산,고양,과천,구리,오산,시흥,군포,의왕,하남,용인,파주,김포,이천,화성,광주,양주,포천,여주,연천,가평,양평,춘천,원주,강릉,동해,태백,속초,삼척,홍천,횡성,영월,평창,정선,철원,화천,양구,인제,고성,양양,청주,충주,제천,청원,보은,영동,옥천,진천,괴산,증평,음성,단양,천안,공주,보령,아산,서산,논산,계룡,금산,연기,부여,서천,청양,홍성,예산,태안,당진,전주,군산,익산,정읍,남원,김제,완주,진안,무주,장수,임실,순창,고창,부안,목포,여수,순천,나주,광양,담양,곡성,구례,소흥,보성,화순,장흥,강진,해남,영암,무안,함평,영광,장성,완도,진도,신안,포항,경주,김천,안동,영주,상주,문경,군위,의성,청송,영양,영덕,청도,고령,성주,칠곡,예천,봉화,울진,울릉,마산,진주,진해,통영,사천,김해,밀양,거제,양산,의령,함안,창녕,고성,남해,하동,산청,함양,거창,합천,제주</span></p><!-- '
#                                        '} SE-TEXT -->\n'
#                                        '                            </div>\n'
#                                        '                        </div>\n'
#                                        '                    </div>\n'
#                                        '                </div>    </div>\n'
#                                        '</div>\n',
#                         'customElements': [],
#                         'decorator': {'articleForm': {'notice': '📲 중고나라 앱 '
#                                                                 '다운받기▶https://tracking.joongna.com/i1\n'
#                                                                 '[AD] [5월 한정] '
#                                                                 '15만원 쓰면 15만원 '
#                                                                 '그대로 캐시백! ▶ '
#                                                                 'https://vvd.bz/b7pk\n'
#                                                                 '🎁 스타벅스 아메리카노 '
#                                                                 '받기!▶https://tracking.joongna.com/i2\n'
#                                                                 '───────────────────\n'
#                                                                 'ㆍ중고나라 사기 통합 '
#                                                                 '조회▶https://tracking.joongna.com/fs\n'
#                                                                 '※ 사기통합조회 DB '
#                                                                 '수집/활용 관련 게시글 '
#                                                                 '작성 동의 확인> '
#                                                                 'https://web.joongna.com/post-policy\n'
#                                                                 '※ 중고나라는 통신판매의 '
#                                                                 '당사자가 아니며 '
#                                                                 '상품정보, 거래에 관한 '
#                                                                 '의무와 책임은 각 '
#                                                                 '판매자에게 있습니다.'},
#                                       'isPlug': False,
#                                       'isShowSuicideSaver': False},
#                         'existScrapAddContent': False,
#                         'gdid': '90000004_00995A623B21533300000000',
#                         'id': 992039731,
#                         'isAutoSourcing': True,
#                         'isBlind': False,
#                         'isDeleteParent': False,
#                         'isEnableExternal': True,
#                         'isEnableScrap': False,
#                         'isEnableSocialPlugin': True,
#                         'isGroupPurchase': False,
#                         'isMarket': True,
#                         'isNewComment': False,
#                         'isNotice': False,
#                         'isOpen': True,
#                         'isPersonalTrade': True,
#                         'isReadable': True,
#                         'isWriteComment': True,
#                         'menu': {'badMenu': False,
#                                  'badMenuByRestrict': False,
#                                  'boardType': 'T',
#                                  'id': 334,
#                                  'menuType': 'B',
#                                  'name': '[상품] 노트북'},
#                         'readCount': 3,
#                         'refArticleId': 992039731,
#                         'replyListOrder': '',
#                         'scrapCount': 0,
#                         'subject': '삼성노트북배터리 NT500R5H 노트북 내장배터리',
#                         'subscribeWriter': {'push': False, 'subscribe': False},
#                         'template': {'isUse': False},
#                         'writeDate': 1684974730173,
#                         'writer': {'baMemberKey': '99a05b21e17a9c03ad4940b92d45470612f87eb910c3ce5d4ba879d60ff95a32',
#                                    'currentPopularMember': False,
#                                    'id': 'kmgbv2366',
#                                    'image': {'isAnimated': False,
#                                              'service': 'BLOG',
#                                              'type': 'c77_77',
#                                              'url': 'https://blogpfthumb-phinf.pstatic.net/MjAyMjAzMjRfNSAg/MDAxNjQ4MDgxNTU4NzI3.XRWDx-xjB2zMlJR8wUoaVdMag28mmk5nTCaOJ0vzbQMg.oILqyg3tQAkqDvbj2Ly3_qEqF8QsfhhPjed6D2HpKPcg.JPEG.kmgbv2366/KakaoTalk_20210615_134050896.jpg/KakaoTalk_20210615_134050896.jpg'},
#                                    'memberKey': 'Fx2VFQMZ6e_BIrkYb3Fjvw',
#                                    'memberLevel': 1,
#                                    'memberLevelIconUrl': 'https://cafe.pstatic.net/levelicon/1/1_1.gif',
#                                    'memberLevelName': '열심회원',
#                                    'nick': 'inho1209'}},
#             'articleId': 992039731,
#             'articleRegion': {'name': '',
#                               'rcode': '',
#                               'regionCode1': '',
#                               'regionCode2': '',
#                               'regionCode3': '',
#                               'regionName1': '',
#                               'regionName2': '',
#                               'regionName3': '',
#                               'type': 'DOMESTIC'},
#             'attaches': [],
#             'authority': {'isDoLike': False,
#                           'isEnableAttachFileDownload': True,
#                           'isHeadModifiable': False,
#                           'isModify': False,
#                           'isMove': False,
#                           'isRemove': False,
#                           'isReport': False,
#                           'isRightClick': False,
#                           'isSharable': True,
#                           'isShowLike': True,
#                           'isShowReply': False,
#                           'isShowStatistics': False,
#                           'isStore': False,
#                           'isWrite': False,
#                           'isWriteComment': True,
#                           'isWriteReply': False},
#             'cafe': {'hasPopularArticle': True,
#                      'id': 10050146,
#                      'image': {'service': 'CAFE',
#                                'type': 'f100_100',
#                                'url': 'https://cafeptthumb-phinf.pstatic.net/MjAyMDA2MTZfMTEx/MDAxNTkyMjY4NzE0MTc0.xov9JGL3QYcc8wDt6vlJihioa49f1Nw6_t7ZL8uYfrYg.9fsFvnLVhXNjdpEo0VPRHzSFc8YsHL08POKGvoHSeUIg.PNG/image.png'},
#                      'introduction': '1초에 평균 4.5건의 신상품 등록! 찾는 그 제품, 중고나라에는 다 '
#                                      '있다!',
#                      'isDormant': False,
#                      'memberCount': 19134034,
#                      'memberLevelIconId': 1,
#                      'name': '중고나라',
#                      'openType': 'O',
#                      'pcCafeName': '중고나라',
#                      'url': 'joonggonara',
#                      'usingMemberLevel': True},
#             'cafeId': 10050146,
#             'commAdSupport': False,
#             'comments': {'alarm': {'isChecked': False, 'isShow': False},
#                          'disableWriteReason': '',
#                          'items': []},
#             'editorVersion': 'SE_ONE',
#             'heads': [],
#             'isReadOnlyMode': False,
#             'isW800': True,
#             'menuId': 334,
#             'readOnlyModeInfo': {'emergency': False,
#                                  'linkToNoticeURL': 'https://section.cafe.naver.com/ca-fe/home/notices/1753',
#                                  'readOnlyModeStatus': False,
#                                  'readOnlyNoticeDuration': '',
#                                  'timeToNotice': False,
#                                  'timeToPreNotice': False},
#             'reviewPersonalStat': {'emotionSatisfactionStat': {'bestCount': 0,
#                                                                'goodCount': 0,
#                                                                'sorryCount': 0}},
#             'saleInfo': {'category1': '50000003',
#                          'category1Name': '디지털/가전',
#                          'category2': '50000091',
#                          'category2Name': '노트북액세서리',
#                          'category3': '50001584',
#                          'category3Name': '노트북용배터리',
#                          'deliveryMethod': '판매자와 직접 연락하세요',
#                          'deliveryTypes': ['MEET', 'DELIVERY'],
#                          'email': 'kmgbv2366@naver.com',
#                          'image': {'fileName': '1-1.jpg',
#                                    'fileSize': 87182,
#                                    'service': 'CAFE',
#                                    'type': 's3',
#                                    'url': 'https://cafeptthumb-phinf.pstatic.net/MjAyMzA1MjRfMjYy/MDAxNjg0ODg3NTczODY1.rvV_M8qUahjqI5MZvrY6f3cbN7C1Nozl2IBQrB8WmrMg.4EgE9o6lniaEMakzARVn7YoAImhe3_8NoYU3P_ZGL34g.JPEG/1-1.jpg'},
#                          'imgUrl': 'https://cafeptthumb-phinf.pstatic.net/MjAyMzA1MjRfMjYy/MDAxNjg0ODg3NTczODY1.rvV_M8qUahjqI5MZvrY6f3cbN7C1Nozl2IBQrB8WmrMg.4EgE9o6lniaEMakzARVn7YoAImhe3_8NoYU3P_ZGL34g.JPEG/1-1.jpg?type=s3',
#                          'isAgreeOpenPhoneNo': True,
#                          'isExperienceMode': False,
#                          'isExpireSafetyPayment': False,
#                          'isFailToLoadStoreFarmProduct': False,
#                          'isNpayRemit': False,
#                          'isOnSale': True,
#                          'isPersonalTrade': True,
#                          'isPhoneAvailable': True,
#                          'isShowPurchaseButton': False,
#                          'isShowRedcardWarning': False,
#                          'isStoreFarmProduct': False,
#                          'isUseOtn': False,
#                          'isUseSafetyPayment': False,
#                          'isWrittenAbroad': False,
#                          'phoneNo': '010-4288-0829',
#                          'price': 40000,
#                          'productCondition': 'ALMOST_NEW',
#                          'productName': '삼성노트북배터리 NT500R5H 노트북 내장배터리',
#                          'regions': [],
#                          'saleStatus': 'SALE',
#                          'type': 'P',
#                          'verifiedSeller': True},
#             'standardReportPopup': {'darkUrl': 'https://srp2.naver.com/report?exit=close&svc=CAF&vsvc=CAF&rcountry=KR&rlang=ko&memtype=Y&ctype=AA19&ctitle=%EC%82%BC%EC%84%B1%EB%85%B8%ED%8A%B8%EB%B6%81%EB%B0%B0%ED%84%B0%EB%A6%AC+NT500R5H+%EB%85%B8%ED%8A%B8%EB%B6%81+%EB%82%B4%EC%9E%A5%EB%B0%B0%ED%84%B0%EB%A6%AC&cnickname=inho1209&cwriter=kmgbv2366&cid=10050146;992039731&dark=enable&env=mobile',
#                                     'normalUrl': 'https://srp2.naver.com/report?exit=close&svc=CAF&vsvc=CAF&rcountry=KR&rlang=ko&memtype=Y&ctype=AA19&ctitle=%EC%82%BC%EC%84%B1%EB%85%B8%ED%8A%B8%EB%B6%81%EB%B0%B0%ED%84%B0%EB%A6%AC+NT500R5H+%EB%85%B8%ED%8A%B8%EB%B6%81+%EB%82%B4%EC%9E%A5%EB%B0%B0%ED%84%B0%EB%A6%AC&cnickname=inho1209&cwriter=kmgbv2366&cid=10050146;992039731&dark=disable&env=mobile',
#                                     'showRemoveAlert': False},
#             'tags': ['노트북배터리', 'NT500R5H', '삼성노트북배터리'],
#             'user': {'appliedAlready': False,
#                      'baMemberKey': '',
#                      'blockMemberKeyList': [],
#                      'currentPopularMember': False,
#                      'image': {'service': 'CAFE',
#                                'type': 'c77_77',
#                                'url': 'https://ssl.pstatic.net/static/cafe/cafe_pc/default/cafe_profile_77.png'},
#                      'isBelowAge14': True,
#                      'isCafeMember': False,
#                      'isGroupId': False,
#                      'isLogin': False,
#                      'isOwner': False,
#                      'memberKey': '',
#                      'memberLevel': 0,
#                      'memberLevelIconUrl': '',
#                      'memberLevelName': '',
#                      'nick': '',
#                      'permission': {'isActivityStopExecutable': False,
#                                     'isBoardStaff': False,
#                                     'isCafeManager': False,
#                                     'isEntireBoardStaff': False,
#                                     'isMemberStaff': False,
#                                     'isNoticeRegistrable': False,
#                                     'isOnlyOptionalBoardStaff': False,
#                                     'isViceManager': False}}}}
# {'result': {'advert': {'daAdvertDivId': 'DaAdvert',
#                        'daAdvertUnitId': 'm_cafe',
#                        'type': 'DA'},
#             'article': {'commentCount': 0,
#                         'contentHtml': '<div class="se-viewer '
#                                        'se-theme-default" lang="ko-KR">\n'
#                                        '    <!-- SE_DOC_HEADER_START -->\n'
#                                        '    <!--@CONTENTS_HEADER-->\n'
#                                        '    <!-- SE_DOC_HEADER_END -->\n'
#                                        '    <div class="se-main-container">\n'
#                                        '                <div '
#                                        'class="se-component se-text '
#                                        'se-l-default" '
#                                        'id="SE-4b9732fc-fa93-11ed-aafa-ff1b46173f3c">\n'
#                                        '                    <div '
#                                        'class="se-component-content">\n'
#                                        '                        <div '
#                                        'class="se-section se-section-text '
#                                        'se-l-default">\n'
#                                        '                            <div '
#                                        'class="se-module se-module-text">\n'
#                                        '                                    '
#                                        '<!-- SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " style="" '
#                                        'id="SE-8607fbd2-fa93-11ed-aafa-9f35209c578c"><span '
#                                        'style="" class="se-fs- se-ff-   " '
#                                        'id="SE-93b34852-fa93-11ed-aafa-1d09f4b4880b">👆 '
#                                        '중고나라에도 앱이 있다는 것을 아시나요? </span></p><!-- '
#                                        '} SE-TEXT --><!-- SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " style="" '
#                                        'id="SE-860822e4-fa93-11ed-aafa-b3e7d9ab4e5b"><span '
#                                        'style="" class="se-fs- se-ff-   " '
#                                        'id="SE-93b36f63-fa93-11ed-aafa-af2de7096195">위에 '
#                                        '다운로드 링크를 통해 중고나라 앱을 다운로드해주세요. '
#                                        '</span></p><!-- } SE-TEXT --><!-- '
#                                        'SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " style="" '
#                                        'id="SE-860822e6-fa93-11ed-aafa-017221e55fb5"><span '
#                                        'style="" class="se-fs- se-ff-   " '
#                                        'id="SE-93b36f64-fa93-11ed-aafa-b1395cfd7dbd">─────────────────── '
#                                        '</span></p><!-- } SE-TEXT --><!-- '
#                                        'SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " style="" '
#                                        'id="SE-860822e8-fa93-11ed-aafa-cf46beaf8be9"><span '
#                                        'style="" class="se-fs- se-ff-   " '
#                                        'id="SE-93b39675-fa93-11ed-aafa-d356f18d2a77">※ '
#                                        '등록한 게시글이 회원의 신고를 받거나 이상거래로 모니터링 될 경우 '
#                                        '중고나라 사기통합조회 DB로 수집/활용될 수 '
#                                        '있습니다.</span></p><!-- } SE-TEXT --><!-- '
#                                        'SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " style="" '
#                                        'id="SE-860822ea-fa93-11ed-aafa-0f1ad5901292"><span '
#                                        'style="" class="se-fs- se-ff-   " '
#                                        'id="SE-93b3bd86-fa93-11ed-aafa-efa9645783e6">\u200b</span></p><!-- '
#                                        '} SE-TEXT --><!-- SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " style="" '
#                                        'id="SE-860822ec-fa93-11ed-aafa-5f1d8c271594"><span '
#                                        'style="" class="se-fs- se-ff-   " '
#                                        'id="SE-93b3bd87-fa93-11ed-aafa-b531479d0aa0">맥북에어 '
#                                        'm1 램8G SSD 256G 2020년 기본이고 '
#                                        '</span></p><!-- } SE-TEXT --><!-- '
#                                        'SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " style="" '
#                                        'id="SE-860822ee-fa93-11ed-aafa-8d3c76dd37df"><span '
#                                        'style="" class="se-fs- se-ff-   " '
#                                        'id="SE-93b3e498-fa93-11ed-aafa-55b9d022fd2b">외장보호 '
#                                        '하드케이스, 박스, 충전기포함 풀박스입니다. '
#                                        '</span></p><!-- } SE-TEXT --><!-- '
#                                        'SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " style="" '
#                                        'id="SE-860822f0-fa93-11ed-aafa-11a8918cfaf4"><span '
#                                        'style="" class="se-fs- se-ff-   " '
#                                        'id="SE-93b3e499-fa93-11ed-aafa-a9bc5bb64f05">새거처럼 '
#                                        '아주 깨끗합니다.</span></p><!-- } SE-TEXT '
#                                        '--><!-- SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " style="" '
#                                        'id="SE-860822f2-fa93-11ed-aafa-bb0e5652dca6"><span '
#                                        'style="" class="se-fs- se-ff-   " '
#                                        'id="SE-93b40baa-fa93-11ed-aafa-0bf84bed80e2">직거래는 '
#                                        '용인시청, 서울 방배역에서 할게요.^^</span></p><!-- } '
#                                        'SE-TEXT -->\n'
#                                        '                            </div>\n'
#                                        '                        </div>\n'
#                                        '                    </div>\n'
#                                        '                </div>                '
#                                        '<div class="se-component se-image '
#                                        'se-l-default" '
#                                        'id="SE-8604795d-fa93-11ed-aafa-f721ea1902f6">\n'
#                                        '                    <div '
#                                        'class="se-component-content '
#                                        'se-component-content-extend">\n'
#                                        '                        <div '
#                                        'class="se-section se-section-image '
#                                        'se-l-default se-section-align-" >\n'
#                                        '                                <div '
#                                        'class="se-module se-module-image" '
#                                        'style="">\n'
#                                        '                                    <a '
#                                        'href="#" class="se-module-image-link '
#                                        '__se_image_link __se_link" style="" '
#                                        'onclick="return false;" '
#                                        'data-linktype="img" '
#                                        'data-linkdata=\'{"id" : '
#                                        '"SE-8604795d-fa93-11ed-aafa-f721ea1902f6", '
#                                        '"src" : '
#                                        '"https://cafeptthumb-phinf.pstatic.net/MjAyMzA1MjVfMjk3/MDAxNjg0OTc0NzIzNTA1.2socuPU49qR8nW_1O7VWTXUar9mlqfQm1YtDq4QBZGYg.-1-gdYBkZiol-S3nlTX-W4qCsAyE_SGYojfBEx7B2tUg.JPEG/20230525%EF%BC%BF090626.jpg", '
#                                        '"originalWidth" : "1280", '
#                                        '"originalHeight" : "2276", "linkUse" : '
#                                        '"false", "link" : ""}\'>\n'
#                                        '                                        '
#                                        '<img '
#                                        'src="https://cafeptthumb-phinf.pstatic.net/MjAyMzA1MjVfMjk3/MDAxNjg0OTc0NzIzNTA1.2socuPU49qR8nW_1O7VWTXUar9mlqfQm1YtDq4QBZGYg.-1-gdYBkZiol-S3nlTX-W4qCsAyE_SGYojfBEx7B2tUg.JPEG/20230525%EF%BC%BF090626.jpg?type=w1600" '
#                                        'alt="" class="se-image-resource" />\n'
#                                        '                                    '
#                                        '</a>\n'
#                                        '                                '
#                                        '</div>\n'
#                                        '                        </div>\n'
#                                        '                    </div>\n'
#                                        '                </div>\n'
#                                        '                <div '
#                                        'class="se-component se-image '
#                                        'se-l-default" '
#                                        'id="SE-8604c77e-fa93-11ed-aafa-412f0dadf88b">\n'
#                                        '                    <div '
#                                        'class="se-component-content '
#                                        'se-component-content-extend">\n'
#                                        '                        <div '
#                                        'class="se-section se-section-image '
#                                        'se-l-default se-section-align-" >\n'
#                                        '                                <div '
#                                        'class="se-module se-module-image" '
#                                        'style="">\n'
#                                        '                                    <a '
#                                        'href="#" class="se-module-image-link '
#                                        '__se_image_link __se_link" style="" '
#                                        'onclick="return false;" '
#                                        'data-linktype="img" '
#                                        'data-linkdata=\'{"id" : '
#                                        '"SE-8604c77e-fa93-11ed-aafa-412f0dadf88b", '
#                                        '"src" : '
#                                        '"https://cafeptthumb-phinf.pstatic.net/MjAyMzA1MjVfMjE1/MDAxNjg0OTc0NzIyOTIz.jUB_jRT06L2jyEuEIdd2E4wqI6oknyNA36H8R7s-eLQg.64Lqigfss1m5MNpWx504wrKXAoeyerSmrZCVmwmn9JIg.JPEG/20230525%EF%BC%BF090728.jpg", '
#                                        '"originalWidth" : "1280", '
#                                        '"originalHeight" : "720", "linkUse" : '
#                                        '"false", "link" : ""}\'>\n'
#                                        '                                        '
#                                        '<img '
#                                        'src="https://cafeptthumb-phinf.pstatic.net/MjAyMzA1MjVfMjE1/MDAxNjg0OTc0NzIyOTIz.jUB_jRT06L2jyEuEIdd2E4wqI6oknyNA36H8R7s-eLQg.64Lqigfss1m5MNpWx504wrKXAoeyerSmrZCVmwmn9JIg.JPEG/20230525%EF%BC%BF090728.jpg?type=w1600" '
#                                        'alt="" class="se-image-resource" />\n'
#                                        '                                    '
#                                        '</a>\n'
#                                        '                                '
#                                        '</div>\n'
#                                        '                        </div>\n'
#                                        '                    </div>\n'
#                                        '                </div>\n'
#                                        '                <div '
#                                        'class="se-component se-image '
#                                        'se-l-default" '
#                                        'id="SE-860563c1-fa93-11ed-aafa-27bc2ee01469">\n'
#                                        '                    <div '
#                                        'class="se-component-content '
#                                        'se-component-content-normal">\n'
#                                        '                        <div '
#                                        'class="se-section se-section-image '
#                                        'se-l-default se-section-align-" '
#                                        'style="max-width:604px;">\n'
#                                        '                                <div '
#                                        'class="se-module se-module-image" '
#                                        'style="">\n'
#                                        '                                    <a '
#                                        'href="#" class="se-module-image-link '
#                                        '__se_image_link __se_link" style="" '
#                                        'onclick="return false;" '
#                                        'data-linktype="img" '
#                                        'data-linkdata=\'{"id" : '
#                                        '"SE-860563c1-fa93-11ed-aafa-27bc2ee01469", '
#                                        '"src" : '
#                                        '"https://cafeptthumb-phinf.pstatic.net/MjAyMzA1MjVfNTYg/MDAxNjg0OTc0NzIzNTcx.2-nxK7DpZHPd1vaPhJiQJKzVx1Y-U7ny_k5ejnIrb2Eg.gQG8bUxzJqh4XAXTpgS96FsrxioRF5JJ-L0w4Hgq6Lwg.PNG/1684973818062.png", '
#                                        '"originalWidth" : "604", '
#                                        '"originalHeight" : "340", "linkUse" : '
#                                        '"false", "link" : ""}\'>\n'
#                                        '                                        '
#                                        '<img '
#                                        'src="https://cafeptthumb-phinf.pstatic.net/MjAyMzA1MjVfNTYg/MDAxNjg0OTc0NzIzNTcx.2-nxK7DpZHPd1vaPhJiQJKzVx1Y-U7ny_k5ejnIrb2Eg.gQG8bUxzJqh4XAXTpgS96FsrxioRF5JJ-L0w4Hgq6Lwg.PNG/1684973818062.png?type=w1600" '
#                                        'alt="" class="se-image-resource" />\n'
#                                        '                                    '
#                                        '</a>\n'
#                                        '                                '
#                                        '</div>\n'
#                                        '                        </div>\n'
#                                        '                    </div>\n'
#                                        '                </div>\n'
#                                        '                <div '
#                                        'class="se-component se-image '
#                                        'se-l-default" '
#                                        'id="SE-8605159f-fa93-11ed-aafa-8fb083f7a507">\n'
#                                        '                    <div '
#                                        'class="se-component-content '
#                                        'se-component-content-normal">\n'
#                                        '                        <div '
#                                        'class="se-section se-section-image '
#                                        'se-l-default se-section-align-" '
#                                        'style="max-width:652px;">\n'
#                                        '                                <div '
#                                        'class="se-module se-module-image" '
#                                        'style="">\n'
#                                        '                                    <a '
#                                        'href="#" class="se-module-image-link '
#                                        '__se_image_link __se_link" style="" '
#                                        'onclick="return false;" '
#                                        'data-linktype="img" '
#                                        'data-linkdata=\'{"id" : '
#                                        '"SE-8605159f-fa93-11ed-aafa-8fb083f7a507", '
#                                        '"src" : '
#                                        '"https://cafeptthumb-phinf.pstatic.net/MjAyMzA1MjVfMTE3/MDAxNjg0OTc0NzIyNjA0.peR6APpIlSjIgc8ZBSwu-bbGFG3AMgQeAixRj6hbxoIg.ROmTLLMNSdm1I9yhWn6h0k6zhAW9FvZI70L4f_mnQ1Mg.PNG/1684973807901.png", '
#                                        '"originalWidth" : "652", '
#                                        '"originalHeight" : "692", "linkUse" : '
#                                        '"false", "link" : ""}\'>\n'
#                                        '                                        '
#                                        '<img '
# ...
#                                        'class="se-fs-fs11 se-ff-system  '
#                                        'se-style-unset " '
#                                        'id="SE-33eb261f-121b-471e-aed4-48d5b00a636f"><b>삼성 '
#                                        'DDR4 16G 21300외산 DDR3 2G 8500,SK하이닉스 '
#                                        'DDR3 2G 8500,삼성 DDR3 2G 8500,외산 DDR3 '
#                                        '2G 10600</b></span></p><!-- } SE-TEXT '
#                                        '--><!-- SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " '
#                                        'style="line-height:1.5;" '
#                                        'id="SE-acec0254-68e0-4642-b160-8f7167cbe8a5"><span '
#                                        'style="color:#ffffff;background-color:#ffffff;" '
#                                        'class="se-fs-fs11 se-ff-system  '
#                                        'se-style-unset " '
#                                        'id="SE-fb58bcce-04f4-481b-b109-09aa9466cae1"><b>SK하이닉스 '
#                                        'DDR3 2G 10600,삼성 DDR3 2G 10600,삼성 '
#                                        'DDR3L 4G 12800 저전력,SK하이닉스 DDR3L 8G '
#                                        '12800 저전력</b></span></p><!-- } SE-TEXT '
#                                        '--><!-- SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " '
#                                        'style="line-height:1.5;" '
#                                        'id="SE-b8021a44-aba2-4006-a2cd-cdb71ca40612"><span '
#                                        'style="color:#ffffff;background-color:#ffffff;" '
#                                        'class="se-fs-fs11 se-ff-system  '
#                                        'se-style-unset " '
#                                        'id="SE-a168d015-aea7-4b97-bcb7-5b7fd1802002"><b>삼성 '
#                                        'DDR3L 8G 12800 저전력,외산 DDR4 8G 19200,삼성 '
#                                        'DDR4 8G 19200,삼성 DDR4 16G '
#                                        '19200</b></span></p><!-- } SE-TEXT '
#                                        '--><!-- SE-TEXT { --><p '
#                                        'class="se-text-paragraph '
#                                        'se-text-paragraph-align- " '
#                                        'style="line-height:1.5;" '
#                                        'id="SE-23531726-93b3-4906-921f-ed223be60f14"><span '
#                                        'style="color:#ffffff;background-color:#ffffff;" '
#                                        'class="se-fs-fs11 se-ff-system  '
#                                        'se-style-unset " '
#                                        'id="SE-461b6d4d-46a2-4184-98c4-03bee7c9e6c6"><b>삼성 '
#                                        'DDR4 16G 21300</b></span></p><!-- } '
#                                        'SE-TEXT -->\n'
#                                        '                            </div>\n'
#                                        '                        </div>\n'
#                                        '                    </div>\n'
#                                        '                </div>    </div>\n'
#                                        '</div>\n',
#                         'customElements': [],
#                         'decorator': {'articleForm': {'notice': '📲 중고나라 앱 '
#                                                                 '다운받기▶https://tracking.joongna.com/i1\n'
#                                                                 '[AD] [5월 한정] '
#                                                                 '15만원 쓰면 15만원 '
#                                                                 '그대로 캐시백! ▶ '
#                                                                 'https://vvd.bz/b7pk\n'
#                                                                 '🎁 스타벅스 아메리카노 '
#                                                                 '받기!▶https://tracking.joongna.com/i2\n'
#                                                                 '───────────────────\n'
#                                                                 'ㆍ중고나라 사기 통합 '
#                                                                 '조회▶https://tracking.joongna.com/fs\n'
#                                                                 '※ 사기통합조회 DB '
#                                                                 '수집/활용 관련 게시글 '
#                                                                 '작성 동의 확인> '
#                                                                 'https://web.joongna.com/post-policy\n'
#                                                                 '※ 중고나라는 통신판매의 '
#                                                                 '당사자가 아니며 '
#                                                                 '상품정보, 거래에 관한 '
#                                                                 '의무와 책임은 각 '
#                                                                 '판매자에게 있습니다.'},
#                                       'isPlug': False,
#                                       'isShowSuicideSaver': False},
#                         'existScrapAddContent': False,
#                         'gdid': '90000004_00995A623B214F7F00000000',
#                         'id': 992038783,
#                         'isAutoSourcing': True,
#                         'isBlind': False,
#                         'isDeleteParent': False,
#                         'isEnableExternal': True,
#                         'isEnableScrap': True,
#                         'isEnableSocialPlugin': True,
#                         'isGroupPurchase': False,
#                         'isMarket': True,
#                         'isNewComment': False,
#                         'isNotice': False,
#                         'isOpen': True,
#                         'isPersonalTrade': True,
#                         'isReadable': True,
#                         'isWriteComment': True,
#                         'menu': {'badMenu': False,
#                                  'badMenuByRestrict': False,
#                                  'boardType': 'T',
#                                  'id': 334,
#                                  'menuType': 'B',
#                                  'name': '[상품] 노트북'},
#                         'readCount': 3,
#                         'refArticleId': 992038783,
#                         'replyListOrder': '',
#                         'scrapCount': 0,
#                         'subject': '레노버 씽크패드 T470s/T480s/T490s/X1카본 부천당일수령 '
#                                    '당일출고 한정수량',
#                         'subscribeWriter': {'push': False, 'subscribe': False},
#                         'template': {'isUse': False},
#                         'writeDate': 1684974411963,
#                         'writer': {'baMemberKey': '7ea953c019a2340ecb70ff0fd238b2ff433d9bffef7ca5d729bcb9b828bfde44',
#                                    'currentPopularMember': False,
#                                    'id': 'pcmaster05',
#                                    'image': {'isAnimated': False,
#                                              'service': 'BLOG',
#                                              'type': 'c77_77',
#                                              'url': 'https://blogpfthumb-phinf.pstatic.net/MjAyMjA2MjhfMTMg/MDAxNjU2Mzk4MjAxMzg1.Ok27UJ1clU1Mw1nU9AHVNi0Un2sDZpaFnmsZ1mAqIXAg.MrfmcVqh5wjYEBKKLKQLfyBnRa9Z6JMox8qi23xlHhkg.JPEG.pcmaster05/%EB%B8%94%EB%A1%9C%EA%B7%B8_%EB%A1%9C%EA%B3%A0.jpg/%25EB%25B8%2594%25EB%25A1%259C%25EA%25B7%25B8%2B%25EB%25A1%259C%25EA%25B3%25A0.jpg'},
#                                    'memberKey': 'L7KXIvESje-IfRJWNqPIng',
#                                    'memberLevel': 150,
#                                    'memberLevelIconUrl': 'https://cafe.pstatic.net/levelicon/1/1_150.gif',
#                                    'memberLevelName': '◆셀러회원◆',
#                                    'nick': '부천컴스토리'}},
#             'articleId': 992038783,
#             'articleRegion': {'name': '',
#                               'rcode': '',
#                               'regionCode1': '',
#                               'regionCode2': '',
#                               'regionCode3': '',
#                               'regionName1': '',
#                               'regionName2': '',
#                               'regionName3': '',
#                               'type': 'DOMESTIC'},
#             'attaches': [],
#             'authority': {'isDoLike': False,
#                           'isEnableAttachFileDownload': True,
#                           'isHeadModifiable': False,
#                           'isModify': False,
#                           'isMove': False,
#                           'isRemove': False,
#                           'isReport': False,
#                           'isRightClick': True,
#                           'isSharable': True,
#                           'isShowLike': True,
#                           'isShowReply': False,
#                           'isShowStatistics': False,
#                           'isStore': False,
#                           'isWrite': False,
#                           'isWriteComment': True,
#                           'isWriteReply': False},
#             'cafe': {'hasPopularArticle': True,
#                      'id': 10050146,
#                      'image': {'service': 'CAFE',
#                                'type': 'f100_100',
#                                'url': 'https://cafeptthumb-phinf.pstatic.net/MjAyMDA2MTZfMTEx/MDAxNTkyMjY4NzE0MTc0.xov9JGL3QYcc8wDt6vlJihioa49f1Nw6_t7ZL8uYfrYg.9fsFvnLVhXNjdpEo0VPRHzSFc8YsHL08POKGvoHSeUIg.PNG/image.png'},
#                      'introduction': '1초에 평균 4.5건의 신상품 등록! 찾는 그 제품, 중고나라에는 다 '
#                                      '있다!',
#                      'isDormant': False,
#                      'memberCount': 19134034,
#                      'memberLevelIconId': 1,
#                      'name': '중고나라',
#                      'openType': 'O',
#                      'pcCafeName': '중고나라',
#                      'url': 'joonggonara',
#                      'usingMemberLevel': True},
#             'cafeId': 10050146,
#             'commAdSupport': False,
#             'comments': {'alarm': {'isChecked': False, 'isShow': False},
#                          'disableWriteReason': '',
#                          'items': []},
#             'editorVersion': 'SE_ONE',
#             'heads': [],
#             'isReadOnlyMode': False,
#             'isW800': True,
#             'menuId': 334,
#             'readOnlyModeInfo': {'emergency': False,
#                                  'linkToNoticeURL': 'https://section.cafe.naver.com/ca-fe/home/notices/1753',
#                                  'readOnlyModeStatus': False,
#                                  'readOnlyNoticeDuration': '',
#                                  'timeToNotice': False,
#                                  'timeToPreNotice': False},
#             'reviewPersonalStat': {'emotionSatisfactionStat': {'bestCount': 0,
#                                                                'goodCount': 0,
#                                                                'sorryCount': 0}},
#             'saleInfo': {'deliveryMethod': '판매자와 직접 연락하세요',
#                          'deliveryTypes': ['MEET'],
#                          'email': 'pcmaster05@naver.com',
#                          'image': {'fileName': '0.메인이미지.jpg',
#                                    'fileSize': 228320,
#                                    'service': 'CAFE',
#                                    'type': 's3',
#                                    'url': 'https://cafeptthumb-phinf.pstatic.net/MjAyMzA1MjVfMjkz/MDAxNjg0OTc0MzMzNTU0.e65Pt79byVB_mjXjKGZvLoe_G3GXUJ0P7apV69Xn2tgg.7ir6e2tWWXQN3jn47UWLPqnu_d0yHFD_6Ku9Rl539WIg.JPEG/0.%EB%A9%94%EC%9D%B8%EC%9D%B4%EB%AF%B8%EC%A7%80.jpg'},
#                          'imgUrl': 'https://cafeptthumb-phinf.pstatic.net/MjAyMzA1MjVfMjkz/MDAxNjg0OTc0MzMzNTU0.e65Pt79byVB_mjXjKGZvLoe_G3GXUJ0P7apV69Xn2tgg.7ir6e2tWWXQN3jn47UWLPqnu_d0yHFD_6Ku9Rl539WIg.JPEG/0.%2525EB%2525A9%252594%2525EC%25259D%2525B8%2525EC%25259D%2525B4%2525EB%2525AF%2525B8%2525EC%2525A7%252580.jpg?type=s3',
#                          'isAgreeOpenPhoneNo': False,
#                          'isExperienceMode': False,
#                          'isExpireSafetyPayment': False,
#                          'isFailToLoadStoreFarmProduct': False,
#                          'isNpayRemit': False,
#                          'isOnSale': True,
#                          'isPersonalTrade': True,
#                          'isPhoneAvailable': True,
#                          'isShowPurchaseButton': False,
#                          'isShowRedcardWarning': False,
#                          'isStoreFarmProduct': False,
#                          'isUseOtn': False,
#                          'isUseSafetyPayment': False,
#                          'isWrittenAbroad': False,
#                          'price': 2000,
#                          'productCondition': 'USED',
#                          'productName': '레노버 씽크패드 T470s/T480s/T490s/X1카본 '
#                                         '부천당일수령 당일출고 한정수량',
#                          'regions': [],
#                          'saleStatus': 'SALE',
#                          'type': 'P',
#                          'verifiedSeller': True},
#             'standardReportPopup': {'darkUrl': 'https://srp2.naver.com/report?exit=close&svc=CAF&vsvc=CAF&rcountry=KR&rlang=ko&memtype=Y&ctype=AA19&ctitle=%EB%A0%88%EB%85%B8%EB%B2%84+%EC%94%BD%ED%81%AC%ED%8C%A8%EB%93%9C+T470s%2FT480s%2FT490s%2FX1%EC%B9%B4%EB%B3%B8+%EB%B6%80%EC%B2%9C%EB%8B%B9%EC%9D%BC..&cnickname=%EB%B6%80%EC%B2%9C%EC%BB%B4%EC%8A%A4%ED%86%A0%EB%A6%AC&cwriter=pcmaster05&cid=10050146;992038783&dark=enable&env=mobile',
#                                     'normalUrl': 'https://srp2.naver.com/report?exit=close&svc=CAF&vsvc=CAF&rcountry=KR&rlang=ko&memtype=Y&ctype=AA19&ctitle=%EB%A0%88%EB%85%B8%EB%B2%84+%EC%94%BD%ED%81%AC%ED%8C%A8%EB%93%9C+T470s%2FT480s%2FT490s%2FX1%EC%B9%B4%EB%B3%B8+%EB%B6%80%EC%B2%9C%EB%8B%B9%EC%9D%BC..&cnickname=%EB%B6%80%EC%B2%9C%EC%BB%B4%EC%8A%A4%ED%86%A0%EB%A6%AC&cwriter=pcmaster05&cid=10050146;992038783&dark=disable&env=mobile',
#                                     'showRemoveAlert': False},
#             'tags': ['삼성노트북',
#                      '레노버노트북',
#                      '터치노트북',
#                      '레노버T470S',
#                      '레노버T470',
#                      '레노버T460',
#                      '레노버T450',
#                      '레노버T440',
#                      '삼성NT450R4J',
#                      '화상수업'],
#             'user': {'appliedAlready': False,
#                      'baMemberKey': '',
#                      'blockMemberKeyList': [],
#                      'currentPopularMember': False,
#                      'image': {'service': 'CAFE',
#                                'type': 'c77_77',
#                                'url': 'https://ssl.pstatic.net/static/cafe/cafe_pc/default/cafe_profile_77.png'},
#                      'isBelowAge14': True,
#                      'isCafeMember': False,
#                      'isGroupId': False,
#                      'isLogin': False,
#                      'isOwner': False,
#                      'memberKey': '',
#                      'memberLevel': 0,
#                      'memberLevelIconUrl': '',
#                      'memberLevelName': '',
#                      'nick': '',
#                      'permission': {'isActivityStopExecutable': False,
#                                     'isBoardStaff': False,
#                                     'isCafeManager': False,
#                                     'isEntireBoardStaff': False,
#                                     'isMemberStaff': False,
#                                     'isNoticeRegistrable': False,
#                                     'isOnlyOptionalBoardStaff': False,
#                                     'isViceManager': False}}}}
